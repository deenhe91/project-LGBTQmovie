# %%
import pandas as pd

page = 'numbers_budgets.html'
df_budgets = pd.read_html(page)
df_budgets
# Out:
# [          0             1                                          2  \
#  0       NaN  Release Date                                      Movie
#  1         1    12/18/2009                                     Avatar
#  2       NaN           NaN                                        NaN
#  3         2    12/18/2015       Star Wars Ep. VII: The Force Awakens
#  4       NaN           NaN                                        NaN
#  5         3     5/24/2007   Pirates of the Caribbean: At World's End
#  6       NaN           NaN                                        NaN
#  7         4     11/6/2015                                    Spectre
#  8       NaN           NaN                                        NaN
#  9         5     7/20/2012                      The Dark Knight Rises
#  10      NaN           NaN                                        NaN
#  11        6      7/2/2013                            The Lone Ranger
# ...

# %%
dfb = df_budgets[0]
headers = dfb.loc[0][1:]
dfb = dfb[[1,2,3,4,5]][1:]
dfb.columns = headers
dfb = dfb.dropna()
dfb
# Out:
# 0     Release Date                                        Movie  \
# 1       12/18/2009                                       Avatar
# 3       12/18/2015         Star Wars Ep. VII: The Force Awakens
# 5        5/24/2007     Pirates of the Caribbean: At World's End
# 7        11/6/2015                                      Spectre
# 9        7/20/2012                        The Dark Knight Rises
# 11        7/2/2013                              The Lone Ranger
# 13        3/9/2012                                  John Carter
# 15      11/24/2010                                      Tangled
# 17        5/4/2007                                 Spider-Man 3
# 19        5/1/2015                  The Avengers: Age of Ultron
# 21       3/25/2016           Batman v Superman: Dawn of Justice
# 23      12/14/2012            The Hobbit: An Unexpected Journey
# 25       7/15/2009       Harry Potter and the Half-Blood Prince
# 27      12/13/2013          The Hobbit: The Desolation of Smaug
# ...
